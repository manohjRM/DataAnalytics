# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dfcc = pd.read_csv("customer_churn.csv")
dfcc.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
contract = dfcc['Contract'].value_counts()
x = contract.index
y = contract.values
plt.bar(x,y,color = 'orange')
plt.xlabel('Contract Type of customer')
plt.ylabel('Count')
plt.title('Distribution of Contract')
# Out:
# Text(0.5, 1.0, 'Distribution of Contract')

# %%
plt.hist(dfcc['MonthlyCharges'],histtype='stepfilled',color='forestgreen')
plt.xlabel('Monthly Charges Incurred')
plt.ylabel("Count")
plt.title('Distribution of Montly Charges')
# Out:
# Text(0.5, 1.0, 'Distribution of Montly Charges')

# %%
plt.scatter(x = dfcc['tenure'],y = dfcc['TotalCharges'])

# %%
dfcc.boxplot(column = 'MonthlyCharges',by = ['PaymentMethod'],color = 'olive')
plt.xlabel('Payment Method of customer')
plt.ylabel("Monthly Charges Incurred")
plt.title('Monthly Charges vs Payment Method')
# Out:
# Text(0.5, 1.0, 'Monthly Charges vs Payment Method')

# %%
dfcars = pd.read_csv("mtcars.csv")
dfcars.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs   am  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0  NaN
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0  1.0
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1  1.0
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1  0.0
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0  0.0
#
#    gear  carb
# 0     4     4
# 1     4     4
# 2     4     1
# 3     3     1
# 4     3     2

# %%
cylinders = dfcars['cyl'].value_counts()
x = cylinders.index
y = cylinders.values
plt.bar(x,y,color = 'orange')
plt.xlabel('Number of Cylinders')
plt.ylabel('Frequency of cars')
# Out:
# Text(0, 0.5, 'Frequency of cars')

# %%
dfcars.isnull().sum()
# Out:
# model    0
# mpg      0
# cyl      0
# disp     0
# hp       0
# drat     0
# wt       0
# qsec     0
# vs       0
# am       4
# gear     0
# carb     0
# dtype: int64

# %%
nullVal = dfcars.isnull().sum()
x = nullVal.index
y = nullVal.values
plt.bar(x,y,color = 'orange')
# Out:
# <BarContainer object of 12 artists>

# %%
plt.hist(dfcars['mpg'])
plt.xlabel('Miles per gallon')
plt.ylabel('Frequency')
plt.title("Miles per gallon Histogram")
# Out:
# Text(0.5, 1.0, 'Miles per gallon Histogram')

# %%
dfcars.boxplot(column = 'hp')
plt.xlabel('Car Horsepower')
plt.title("Box Plot for Horsepower")
# Out:
# Text(0.5, 1.0, 'Box Plot for Horsepower')

# %%
plt.plot([x for x in range(0, 10)],'green',marker='P')

# %%
n = plt.plot(dfcars['model'],dfcars['hp'])
plt.xlabel('Models of Cars')
plt.ylabel('Horsepower of Cars')
plt.title("Model Name Vs Horse power")
plt.xticks(rotation=90)
plt.show()

# %%
x = dfcars['carb']
y = dfcars['gear']
plt.bar(x,y,color = 'orange')
plt.xlabel('Number of carburetor')
plt.ylabel('Number of forwards gears')
plt.title('Carbs vs Gears')
# Out:
# Text(0.5, 1.0, 'Carbs vs Gears')

# %%
plt.hist(dfcars['wt'],bins=30)
plt.xlabel('Weight of Cars')
plt.ylabel('Count')
plt.title('Histogram for the weight values')
# Out:
# Text(0.5, 1.0, 'Histogram for the weight values')

# %%
x = plt.pie(dfcars['cyl'],labels = dfcars['model'])
plt.show()

# %%
plt.stackplot(dfcars['am'],dfcars['carb'])
plt.xlabel('Transmission')
plt.ylabel('Number of Carburetors')
plt.title('Transmission vs Number of Carburetors')
# Out:
# Text(0.5, 1.0, 'Transmission vs Number of Carburetors')
